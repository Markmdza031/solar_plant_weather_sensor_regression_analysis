# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import missingno as msno

# %%
df1 = pd.read_csv('Plant_1_Generation_Data+_Plant_1_Generation_Data.csv')

# %%
# Setting correct format for date 
df1['date_true'] =  pd.to_datetime(df1['Date Time'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Date Time                                     68778 non-null  object
#  1   DATE TIME (Plant 1 Weather Sensor Data.csv)   68774 non-null  object
#  2   Plant Id                                      68778 non-null  int64
#  3   PLANT ID (Plant 1 Weather Sensor Data.csv)    68774 non-null  float64
#  4   Source Key                                    68778 non-null  object
#  5   SOURCE KEY (Plant 1 Weather Sensor Data.csv)  68774 non-null  object
#  6   Ac Power                                      68778 non-null  float64
#  7   Ambient Temperature                           68774 non-null  float64
#  8   Daily Yield                                   68778 non-null  float64
# ...

# %%
# Sort values by date
df1.sort_values(by='date_true', inplace=True)

# %%
# Visualize distribution

fig = plt.figure(figsize = (10,10))
ax = fig.gca()
df1[['Ac Power',
       'Ambient Temperature', 'Daily Yield', 'Dc Power', 'Irradiation',
       'Module Temperature', 'Total Yield']].hist(ax = ax)
plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2568\2843206618.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df1[['Ac Power',

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df1.plot(kind='scatter', x='Ambient Temperature', y='Daily Yield', ax=axs[0], grid=True)
df1.plot(kind='scatter', x='Module Temperature', y='Daily Yield', ax=axs[1], grid=True)
df1.plot(kind='scatter', x='Irradiation', y='Daily Yield', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Daily Yield'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df1.plot(kind='scatter', x='Ambient Temperature', y='Total Yield', ax=axs[0], grid=True)
df1.plot(kind='scatter', x='Module Temperature', y='Total Yield', ax=axs[1], grid=True)
df1.plot(kind='scatter', x='Irradiation', y='Total Yield', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Total Yield'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df1.plot(kind='scatter', x='Ambient Temperature', y='Dc Power', ax=axs[0], grid=True)
df1.plot(kind='scatter', x='Module Temperature', y='Dc Power', ax=axs[1], grid=True)
df1.plot(kind='scatter', x='Irradiation', y='Dc Power', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Dc Power'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df1.plot(kind='scatter', x='Ambient Temperature', y='Ac Power', ax=axs[0], grid=True)
df1.plot(kind='scatter', x='Module Temperature', y='Ac Power', ax=axs[1], grid=True)
df1.plot(kind='scatter', x='Irradiation', y='Ac Power', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Ac Power'>

# %% [markdown]
# # 2nd Plant

# %%
df2 = pd.read_csv('Plant_2_Generation_Data+_Plant_2_Generation_Data.csv')

# %%
df2['date_true'] =  pd.to_datetime(df2['Date Time'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67698 entries, 0 to 67697
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Date Time                                     67698 non-null  object
#  1   DATE TIME (Plant 2 Weather Sensor Data.csv)   67698 non-null  object
#  2   Plant Id                                      67698 non-null  int64
#  3   PLANT ID (Plant 2 Weather Sensor Data.csv)    67698 non-null  int64
#  4   Source Key                                    67698 non-null  object
#  5   SOURCE KEY (Plant 2 Weather Sensor Data.csv)  67698 non-null  object
#  6   Ac Power                                      67698 non-null  float64
#  7   Ambient Temperature                           67698 non-null  float64
#  8   Daily Yield                                   67698 non-null  float64
# ...

# %%
df2.sort_values(by='date_true', inplace=True)

# %%
df2.head(3)
# Out:
#                 Date Time DATE TIME (Plant 2 Weather Sensor Data.csv)  \
# 0   5/15/2020 12:00:00 AM                       5/15/2020 12:00:00 AM
# 21  5/15/2020 12:00:00 AM                       5/15/2020 12:00:00 AM
# 20  5/15/2020 12:00:00 AM                       5/15/2020 12:00:00 AM
#
#     Plant Id  PLANT ID (Plant 2 Weather Sensor Data.csv)       Source Key  \
# 0    4136001                                     4136001  4UPUqMRk7TRMgml
# 21   4136001                                     4136001  xoJJ8DcxJEcupym
# 20   4136001                                     4136001  xMbIugepa2P7lBB
#
#    SOURCE KEY (Plant 2 Weather Sensor Data.csv)  Ac Power  \
# 0                               iq8k7ZNt4Mwm3w0       0.0
# 21                              iq8k7ZNt4Mwm3w0       0.0
# 20                              iq8k7ZNt4Mwm3w0       0.0
#
#     Ambient Temperature  Daily Yield  Dc Power  Irradiation  \
# 0             27.004764       9425.0       0.0          0.0
# ...

# %%
df2.columns
# Out:
# Index(['Date Time', 'DATE TIME (Plant 2 Weather Sensor Data.csv)', 'Plant Id',
#        'PLANT ID (Plant 2 Weather Sensor Data.csv)', 'Source Key',
#        'SOURCE KEY (Plant 2 Weather Sensor Data.csv)', 'Ac Power',
#        'Ambient Temperature', 'Daily Yield', 'Dc Power', 'Irradiation',
#        'Module Temperature', 'Total Yield', 'date_true'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.gca()
df2[['Ac Power',
       'Ambient Temperature', 'Daily Yield', 'Dc Power', 'Irradiation',
       'Module Temperature', 'Total Yield']].hist(ax = ax)
plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2568\2343135501.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df2[['Ac Power',

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df2.plot(kind='scatter', x='Ambient Temperature', y='Daily Yield', ax=axs[0], grid=True)
df2.plot(kind='scatter', x='Module Temperature', y='Daily Yield', ax=axs[1], grid=True)
df2.plot(kind='scatter', x='Irradiation', y='Daily Yield', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Daily Yield'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df2.plot(kind='scatter', x='Ambient Temperature', y='Total Yield', ax=axs[0], grid=True)
df2.plot(kind='scatter', x='Module Temperature', y='Total Yield', ax=axs[1], grid=True)
df2.plot(kind='scatter', x='Irradiation', y='Total Yield', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Total Yield'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df2.plot(kind='scatter', x='Ambient Temperature', y='Dc Power', ax=axs[0], grid=True)
df2.plot(kind='scatter', x='Module Temperature', y='Dc Power', ax=axs[1], grid=True)
df2.plot(kind='scatter', x='Irradiation', y='Dc Power', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Dc Power'>

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
df2.plot(kind='scatter', x='Ambient Temperature', y='Ac Power', ax=axs[0], grid=True)
df2.plot(kind='scatter', x='Module Temperature', y='Ac Power', ax=axs[1], grid=True)
df2.plot(kind='scatter', x='Irradiation', y='Ac Power', ax=axs[2], grid=True)
# Out:
# <AxesSubplot:xlabel='Irradiation', ylabel='Ac Power'>

# %% [markdown]
# # Combine two datasets

# %%
df = pd.concat([df1, df2], axis=0)

# %%
df = df.sort_index()

# %%
df_check = df[['Date Time','Ac Power', 'Dc Power', 'Daily Yield', 'Total Yield', 'Ambient Temperature', 'Irradiation', 'Module Temperature']]

# %%
corr = df_check.corr()
matrix = np.triu(corr)

# %%
corr
# Out:
#                      Ac Power  Dc Power  Daily Yield  Total Yield  \
# Ac Power             1.000000  0.748622     0.047015    -0.044293
# Dc Power             0.748622  1.000000     0.054214    -0.240783
# Daily Yield          0.047015  0.054214     1.000000    -0.039261
# Total Yield         -0.044293 -0.240783    -0.039261     1.000000
# Ambient Temperature  0.574222  0.287512     0.373862     0.168550
# Irradiation          0.884799  0.664418    -0.011747    -0.006764
# Module Temperature   0.852363  0.643254     0.129203     0.028274
#
#                      Ambient Temperature  Irradiation  Module Temperature
# Ac Power                        0.574222     0.884799            0.852363
# Dc Power                        0.287512     0.664418            0.643254
# Daily Yield                     0.373862    -0.011747            0.129203
# Total Yield                     0.168550    -0.006764            0.028274
# ...

# %%
corr.to_excel("output.xlsx")

# %%
cmap = sns.color_palette("vlag", as_cmap=True)

fig = plt.figure(figsize=(10,10))

sns.heatmap(corr, annot=True, cmap=cmap, mask=matrix)
plt.show()
fig.savefig('corrheatmap.png')

# %%
df_check = df_check.reset_index()

# %%
df_date = df_check.groupby('Date Time')[['Ac Power', 'Dc Power', 'Daily Yield', 'Total Yield', 'Ambient Temperature', 'Irradiation', 'Module Temperature']].sum()

# %%
df_date
# Out:
#                            Ac Power       Dc Power    Daily Yield  \
# Date Time
# 5/15/2020 10:00:00 AM  36039.607738  201596.934759   75885.460716
# 5/15/2020 10:00:00 PM      0.000000       0.000000  250339.000000
# 5/15/2020 10:15:00 AM  32573.463333  176181.806904   83909.535714
# 5/15/2020 10:15:00 PM      0.000000       0.000000  250339.000000
# 5/15/2020 10:30:00 AM  30271.078453  147177.635715   92167.308332
# ...                             ...            ...            ...
# 6/9/2020 9:15:00 PM        0.000000       0.000000  312420.000000
# 6/9/2020 9:30:00 AM    36357.731072  212124.421908   67457.717856
# 6/9/2020 9:30:00 PM        0.000000       0.000000  312420.000000
# 6/9/2020 9:45:00 AM    25668.817500  217173.540247   49511.886905
# 6/9/2020 9:45:00 PM        0.000000       0.000000  312420.000000
#
#                         Total Yield  Ambient Temperature  Irradiation  \
# Date Time
# 5/15/2020 10:00:00 AM  1.434043e+10          1331.534285    32.972969
# ...

# %%
df_date.reset_index(inplace=True)

# %%
df_date['Date Time'] = pd.to_datetime(df_date['Date Time'])

# %%
df_yes = df_date.groupby(pd.Grouper(key='Date Time', axis=0, 
                      freq='3D')).sum()

# %%
df_yes.to_csv('12 days.csv')

# %% [markdown]
# # Data Preparation

# %%
feature_cols = ['Irradiation', 'Module Temperature', 'Ambient Temperature']
X = df[feature_cols]
y = df['Ac Power']

# %% [markdown]
# Prior fitting the model, check for multicollinearity, i.e. whether the X variables are highly correlated with each other. If multicollinearity exists between them, it may generate issues when modeling linear regressions.

# %%
#checking for multicollinearity
sns.color_palette("ch:s=-.2,r=.6", as_cmap=True)
sns.heatmap(X.corr(), annot=True)

plt.savefig('heatmap.png',bbox_inches='tight')

# %% [markdown]
# If there are correlation values that are >=0.8, the multicollinearity assumption is being broken. You might need to drop one of the two correlated X variables. Otherwise, you'll have difficulty interpreting your model.
#
# - The coefficients become very sensitive to small changes in the model
# - Reduced precision of the estimated coefficients
#
# Note that, in regression analysis, interpretation of coefficients represents mean change in the Y variable for each 1 unit change in an X variable when you hold all other X variables constant. When you have multicollinearity or highly correlated X variables, it indicates that changes in one of your X variables will be associated with shifts in other X variables. The stronger the correlation, the more difficult it is to change one variable without changing another, so it becomes difficult for the model to estimate the relationship between each X variable and the Y variable independently.

# %%
# drop all nans
df = df.drop(columns=['DATE TIME (Plant 2 Weather Sensor Data.csv)', 'PLANT ID (Plant 2 Weather Sensor Data.csv)', 'SOURCE KEY (Plant 2 Weather Sensor Data.csv)'])

# %%
df = df.dropna()

# %%
df_features = df[['Irradiation', 'Ambient Temperature', 'Ac Power']]

# %%
# drop the module temperature to avoid multicollinearity

feature_cols = ['Irradiation', 'Ambient Temperature']
X = df_features[feature_cols]
y = df_features['Ac Power']

# %%
from sklearn.linear_model import LinearRegression

# %%
#fit the model
lm = LinearRegression()
lm.fit(X, y)

# print intercept and coefficients
print(lm.intercept_)
# pair the feature names with the coefficients
print(list(zip(feature_cols, lm.coef_)))
# Out:
# -35.54141511587875
# [('Irradiation', 1277.5446729609705), ('Ambient Temperature', 1.8209086159296919)]

# %%
# calculate the R-squared
lm.score(X, y)
# Out:
# 0.9789079134819612

# %%
from sklearn.metrics import mean_squared_error
def RMSE(model, X, y):
    predicted = model.predict(X)
    rmse = (np.sqrt(mean_squared_error(y, predicted)))
    print('RMSE is {}'.format(rmse))

# %%
RMSE(lm, X, y)
# Out:
# RMSE is 57.27800277724398

# %%
1 - (1-lm.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1)
# Out:
# 0.9789073000813557

# %% [markdown]
# # Linear Regression

# %%
# code for Irradiation-Ac Power here
model = LinearRegression(fit_intercept=True)
model.fit(df_features['Irradiation'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features['Irradiation'].min()],[df_features['Irradiation'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features.plot(kind='scatter', x='Irradiation', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features['Irradiation'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features['Irradiation'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 1292.2464
# Model intercept: 7.5830
# R-squared:  0.9787937623143446
# RMSE is 57.43278898812398

# %%
# code for Ambient Temperature-Ac Power here
model = LinearRegression(fit_intercept=True)
model.fit(df_features['Ambient Temperature'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features['Ambient Temperature'].min()],[df_features['Ambient Temperature'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features.plot(kind='scatter', x='Ambient Temperature', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features['Ambient Temperature'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features['Ambient Temperature'].values.reshape(-1,1), df_features['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 56.0145
# Model intercept: -1224.3306
# R-squared:  0.3297305782681078
# RMSE is 311.2523385332271

# %% [markdown]
# # For Plant 1

# %%
df_features1 = df_final[df_final['Plant Id'] == 1]

# %%
df_features1 = df_features1[['Irradiation', 'Ambient Temperature', 'Ac Power']]

# %%
clean_dataset(df_features1)
# Out:
#        Irradiation  Ambient Temperature    Ac Power
# 0         0.590902            27.420234  801.962500
# 1         0.590902            27.420234  823.462500
# 2         0.590902            27.420234  846.328571
# 3         0.590902            27.420234  799.737500
# 4         0.590902            27.420234  838.342857
# ...            ...                  ...         ...
# 68773     0.590902            27.420234  817.887500
# 68774     0.590902            27.420234  856.762500
# 68775     0.590902            27.420234  781.171429
# 68776     0.590902            27.420234  841.542857
# 68777     0.590902            27.420234  822.457143
#
# [68774 rows x 3 columns]

# %%
# code for -Ac Power here (Irradiation)
model = LinearRegression(fit_intercept=True)
model.fit(df_features1['Irradiation'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features1['Irradiation'].min()],[df_features1['Irradiation'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features1.plot(kind='scatter', x='Irradiation', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features1['Irradiation'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features1['Irradiation'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 1292.2464
# Model intercept: 7.5830
# R-squared:  0.9787937623143446
# RMSE is 57.43278898812398

# %%
# code for -Ac Power here (Ambient Temperature)
model = LinearRegression(fit_intercept=True)
model.fit(df_features1['Ambient Temperature'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features1['Ambient Temperature'].min()],[df_features1['Ambient Temperature'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features1.plot(kind='scatter', x='Ambient Temperature', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features1['Ambient Temperature'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features1['Ambient Temperature'].values.reshape(-1,1), df_features1['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 85.0557
# Model intercept: -1866.1204
# R-squared:  0.5254836689529361
# RMSE is 271.6775024102155

# %% [markdown]
# # For Plant 2

# %%
df_features2 = df_final[df_final['Plant Id'] == 2]

# %%
df_features2 = df_features2[['Irradiation', 'Ambient Temperature', 'Ac Power']]

# %%
# clean_dataset(df_features1)
# Out:
#        Irradiation  Ambient Temperature    Ac Power
# 0         0.590902            27.420234  801.962500
# 1         0.590902            27.420234  823.462500
# 2         0.590902            27.420234  846.328571
# 3         0.590902            27.420234  799.737500
# 4         0.590902            27.420234  838.342857
# ...            ...                  ...         ...
# 68773     0.590902            27.420234  817.887500
# 68774     0.590902            27.420234  856.762500
# 68775     0.590902            27.420234  781.171429
# 68776     0.590902            27.420234  841.542857
# 68777     0.590902            27.420234  822.457143
#
# [68774 rows x 3 columns]

# %%
# code for -Ac Power here (Irradiation)
model = LinearRegression(fit_intercept=True)
model.fit(df_features2['Irradiation'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features2['Irradiation'].min()],[df_features2['Irradiation'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features2.plot(kind='scatter', x='Irradiation', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features2['Irradiation'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features2['Irradiation'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 913.9875
# Model intercept: 31.7880
# R-squared:  0.6097283789201979
# RMSE is 226.21600946027152

# %%
# code for -Ac Power here (Ambient Temperature)
model = LinearRegression(fit_intercept=True)
model.fit(df_features2['Ambient Temperature'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1))

print('Model slope: %0.4f' % model.coef_[0])
print('Model intercept: %0.4f' % model.intercept_)

# make predictions for min and max x and store them
x_lsl = [[df_features2['Ambient Temperature'].min()],[df_features2['Ambient Temperature'].max()]]
y_lsl = model.predict(x_lsl)
y_lsl

# first, plot the observed data
df_features2.plot(kind='scatter', x='Ambient Temperature', y='Ac Power')

# then, plot the least squares line
plt.plot(x_lsl, y_lsl, c='red', linewidth=2)

print("R-squared: ", model.score(df_features2['Ambient Temperature'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1)))

RMSE(model, df_features2['Ambient Temperature'].values.reshape(-1,1), df_features2['Ac Power'].values.reshape(-1,1))
# Out:
# Model slope: 50.7266
# Model intercept: -1178.3945
# R-squared:  0.3173340037739024
# RMSE is 299.18787305869097
